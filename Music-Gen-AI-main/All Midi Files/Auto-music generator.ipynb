# %%
from music21 import *
import glob
from tqdm import tqdm
import numpy as np
import random
from tensorflow.keras.layers import LSTM,Dense,Input,Dropout
from tensorflow.keras.models import Sequential,Model,load_model
from sklearn.model_selection import train_test_split

# %%
def read_files(file):
    notes=[]
    notes_to_parse=None
    #parse the midi file
    midi=converter.parse(file)
    #seperate all instruments from the file
    instrmt=instrument.partitionByInstrument(midi)
    
    for part in instrmt.parts:
        #fetch data only of Piano instrument
        if 'Piano, Piano right' in str(part):
            notes_to_parse=part.recurse()
        
    #iterate over all the parts of sub stream elements
    #check if element's type is Note or chord
    #if it is chord split them into notes
    for element in notes_to_parse:
        if type(element)==note.Note:
            notes.append(str(element.pitch))
        elif type(element)==chord.Chord:
            notes.append('.'.join(str(n) for n in element.normalOrder))
            
    #return the list of notes
    return notes

#retrieve paths recursively from inside the directories/files
file_path=["muss"]
all_files=glob.glob('C:/Users/lenovo/Downloads/All Midi Files/'+file_path[0]+'/*.mid',recursive=True)

#reading each midi file
notes_array = np.array([read_files(i) for i in tqdm(all_files,position=0,leave=True)])
# Out:
#   0%|                                                                                            | 0/8 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 31
#      28 all_files=glob.glob('C:/Users/lenovo/Downloads/All Midi Files/'+file_path[0]+'/*.mid',recursive=True)
#      30 #reading each midi file
# ---> 31 notes_array = np.array([read_files(i) for i in tqdm(all_files,position=0,leave=True)])
#
# Cell In[11], line 31, in <listcomp>(.0)
#      28 all_files=glob.glob('C:/Users/lenovo/Downloads/All Midi Files/'+file_path[0]+'/*.mid',recursive=True)
#      30 #reading each midi file
# ---> 31 notes_array = np.array([read_files(i) for i in tqdm(all_files,position=0,leave=True)])
#
# Cell In[11], line 17, in read_files(file)
#      12         notes_to_parse=part.recurse()
#      14 #iterate over all the parts of sub stream elements
#      15 #check if element's type is Note or chord
#      16 #if it is chord split them into notes
# ---> 17 for element in notes_to_parse:
#      18     if type(element)==note.Note:
#      19         notes.append(str(element.pitch))
#
# TypeError: 'NoneType' object is not iterable

# %%
#unique notes
notess = sum(notes_array,[])
unique_notes = list(set(notess))
print("Unique Notes:",len(unique_notes))

#notes with their frequency
freq=dict(map(lambda x: (x,notess.count(x)),unique_notes))

#get the threshold frequency
for i in range(30,100,20):
    print(i,":",len(list(filter(lambda x:x[1]>=i,freq.items()))))
# Out:
# Unique Notes: 0
# 30 : 0
# 50 : 0
# 70 : 0
# 90 : 0

# %%
#filter notes greater than threshold i.e. 50
freq_notes=dict(filter(lambda x:x[1]>=50,freq.items()))
#create new notes using the frequent notes
new_notes=[[i for i in j if i in freq_notes] for j in notes_array]

# %%
#dictionary having key as note index and value as note
ind2note=dict(enumerate(freq_notes))
#dictionary having key as note and value as note index
note2ind=dict(map(reversed,ind2note.items()))

# %%
#timestep
timesteps=50
#store values of input and output
x=[] ; y=[]
for i in new_notes:
    for j in range(0,len(i)-timesteps):
        #input will be the current index + timestep
        #output will be the next index after timestep
        inp=i[j:j+timesteps] ; out=i[j+timesteps]
        #append the index value of respective notes
        x.append(list(map(lambda x:note2ind[x],inp)))
        y.append(note2ind[out])
        
x_new=np.array(x)
y_new=np.array(y)

# %%
#reshape input and output for the model
x_new = np.reshape(x_new,(len(x_new),timesteps,1))
y_new = np.reshape(y_new,(-1,1))
#split the input and value into training and testing sets
#80% for training and 20% for testing sets
x_train,x_test,y_train,y_test = train_test_split(x_new,y_new,test_size=0.2,random_state=42)

# %%
#create the model
model = Sequential()
#create two stacked LSTM layer with the latent dimension of 256
model.add(LSTM(256,return_sequences=True,input_shape=(x_new.shape[1],x_new.shape[2])))
model.add(Dropout(0.2))
model.add(LSTM(256))
model.add(Dropout(0.2))
model.add(Dense(256,activation='relu'))
#fully connected layer for the output with softmax activation
model.add(Dense(len(note2ind),activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 50, 256)           264192
#
#  dropout (Dropout)           (None, 50, 256)           0
#
#  lstm_1 (LSTM)               (None, 256)               525312
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense (Dense)               (None, 256)               65792
#
#  dense_1 (Dense)             (None, 10)                2570
#
# =================================================================
# Total params: 857866 (3.27 MB)
# Trainable params: 857866 (3.27 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
#compile the model using Adam optimizer
model.compile(loss='sparse_categorical_crossentropy', optimizer='adam',metrics=['accuracy'])
#train the model on training sets and validate on testing sets
model.fit(
    x_train,y_train,
    batch_size=128,epochs=80,
    validation_data=(x_test,y_test))
# Out:
# Epoch 1/80
# 5/5 [==============================] - 7s 729ms/step - loss: 2.2532 - accuracy: 0.1821 - val_loss: 2.1876 - val_accuracy: 0.2484
# Epoch 2/80
# 5/5 [==============================] - 2s 423ms/step - loss: 2.1660 - accuracy: 0.2540 - val_loss: 2.0106 - val_accuracy: 0.3057
# Epoch 3/80
# 5/5 [==============================] - 2s 404ms/step - loss: 1.9916 - accuracy: 0.2891 - val_loss: 1.8074 - val_accuracy: 0.2866
# Epoch 4/80
# 5/5 [==============================] - 2s 463ms/step - loss: 1.9318 - accuracy: 0.3003 - val_loss: 1.7974 - val_accuracy: 0.2675
# Epoch 5/80
# 5/5 [==============================] - 2s 389ms/step - loss: 1.8641 - accuracy: 0.3067 - val_loss: 1.7510 - val_accuracy: 0.3439
# Epoch 6/80
# 5/5 [==============================] - 2s 476ms/step - loss: 1.7874 - accuracy: 0.3227 - val_loss: 1.7079 - val_accuracy: 0.3376
# Epoch 7/80
# 5/5 [==============================] - 2s 429ms/step - loss: 1.7359 - accuracy: 0.3498 - val_loss: 1.7178 - val_accuracy: 0.3185
# Epoch 8/80
# 5/5 [==============================] - 2s 408ms/step - loss: 1.7134 - accuracy: 0.3211 - val_loss: 1.7259 - val_accuracy: 0.3121
# Epoch 9/80
# 5/5 [==============================] - 2s 391ms/step - loss: 1.6760 - accuracy: 0.3403 - val_loss: 1.6879 - val_accuracy: 0.3185
# Epoch 10/80
# 5/5 [==============================] - 2s 458ms/step - loss: 1.6948 - accuracy: 0.3435 - val_loss: 1.6399 - val_accuracy: 0.3439
# Epoch 11/80
# 5/5 [==============================] - 2s 412ms/step - loss: 1.7082 - accuracy: 0.3323 - val_loss: 1.6302 - val_accuracy: 0.3121
# Epoch 12/80
# 5/5 [==============================] - 2s 515ms/step - loss: 1.6586 - accuracy: 0.3387 - val_loss: 1.6883 - val_accuracy: 0.3376
# Epoch 13/80
# 5/5 [==============================] - 2s 474ms/step - loss: 1.6725 - accuracy: 0.3498 - val_loss: 1.6305 - val_accuracy: 0.3567
# Epoch 53/80
# 5/5 [==============================] - 2s 455ms/step - loss: 0.8119 - accuracy: 0.6581 - val_loss: 1.1947 - val_accuracy: 0.4713
# Epoch 54/80
# 5/5 [==============================] - 2s 452ms/step - loss: 0.8483 - accuracy: 0.6406 - val_loss: 1.1068 - val_accuracy: 0.5350
# Epoch 55/80
# 5/5 [==============================] - 2s 448ms/step - loss: 0.8298 - accuracy: 0.6661 - val_loss: 1.2069 - val_accuracy: 0.5223
# Epoch 56/80
# 5/5 [==============================] - 2s 458ms/step - loss: 0.8044 - accuracy: 0.6470 - val_loss: 1.1476 - val_accuracy: 0.5350
# Epoch 57/80
# 5/5 [==============================] - 2s 485ms/step - loss: 0.8978 - accuracy: 0.6550 - val_loss: 1.2683 - val_accuracy: 0.4331
# Epoch 58/80
# 5/5 [==============================] - 2s 458ms/step - loss: 0.8966 - accuracy: 0.6629 - val_loss: 1.2251 - val_accuracy: 0.4968
# Epoch 59/80
# 5/5 [==============================] - 2s 453ms/step - loss: 0.8473 - accuracy: 0.6518 - val_loss: 1.2333 - val_accuracy: 0.5032
# Epoch 60/80
# 5/5 [==============================] - 2s 450ms/step - loss: 0.7750 - accuracy: 0.6789 - val_loss: 1.0862 - val_accuracy: 0.5032
# Epoch 61/80
# 5/5 [==============================] - 2s 450ms/step - loss: 0.7385 - accuracy: 0.7045 - val_loss: 1.0461 - val_accuracy: 0.6178
# Epoch 62/80
# 5/5 [==============================] - 2s 452ms/step - loss: 0.6894 - accuracy: 0.7300 - val_loss: 1.0245 - val_accuracy: 0.5732
# Epoch 63/80
# 5/5 [==============================] - 2s 442ms/step - loss: 0.6603 - accuracy: 0.7396 - val_loss: 0.9675 - val_accuracy: 0.5924
# Epoch 64/80
# 5/5 [==============================] - 2s 451ms/step - loss: 0.6261 - accuracy: 0.7588 - val_loss: 0.9877 - val_accuracy: 0.6433
# Epoch 65/80
# 5/5 [==============================] - 2s 450ms/step - loss: 0.6037 - accuracy: 0.7875 - val_loss: 0.9676 - val_accuracy: 0.6688
# Epoch 66/80
# 5/5 [==============================] - 2s 442ms/step - loss: 0.5830 - accuracy: 0.7716 - val_loss: 0.9533 - val_accuracy: 0.6433
# Epoch 67/80
# 5/5 [==============================] - 2s 446ms/step - loss: 0.5522 - accuracy: 0.7939 - val_loss: 0.9299 - val_accuracy: 0.6561
# Epoch 68/80
# 5/5 [==============================] - 2s 443ms/step - loss: 0.5225 - accuracy: 0.7987 - val_loss: 0.9521 - val_accuracy: 0.6879
# Epoch 69/80
# 5/5 [==============================] - 2s 450ms/step - loss: 0.5263 - accuracy: 0.8179 - val_loss: 0.9311 - val_accuracy: 0.6752
# Epoch 70/80
# 5/5 [==============================] - 2s 453ms/step - loss: 0.5109 - accuracy: 0.8019 - val_loss: 0.9786 - val_accuracy: 0.6879
# Epoch 71/80
# 5/5 [==============================] - 2s 435ms/step - loss: 0.5016 - accuracy: 0.8163 - val_loss: 0.9304 - val_accuracy: 0.6561
# Epoch 72/80
# 5/5 [==============================] - 2s 442ms/step - loss: 0.5103 - accuracy: 0.7923 - val_loss: 0.9653 - val_accuracy: 0.6752
# Epoch 73/80
# 5/5 [==============================] - 2s 451ms/step - loss: 0.4937 - accuracy: 0.8083 - val_loss: 0.9019 - val_accuracy: 0.6943
# Epoch 74/80
# 5/5 [==============================] - 2s 442ms/step - loss: 0.4741 - accuracy: 0.8291 - val_loss: 0.9300 - val_accuracy: 0.7134
# Epoch 75/80
# 5/5 [==============================] - 2s 442ms/step - loss: 0.4477 - accuracy: 0.8450 - val_loss: 0.9399 - val_accuracy: 0.7006
# Epoch 76/80
# 5/5 [==============================] - 3s 578ms/step - loss: 0.4402 - accuracy: 0.8339 - val_loss: 0.8569 - val_accuracy: 0.7580
# Epoch 77/80
# 5/5 [==============================] - 2s 472ms/step - loss: 0.4242 - accuracy: 0.8594 - val_loss: 0.8979 - val_accuracy: 0.7325
# Epoch 78/80
# 5/5 [==============================] - 2s 464ms/step - loss: 0.4372 - accuracy: 0.8450 - val_loss: 0.8243 - val_accuracy: 0.7643
# Epoch 79/80
# 5/5 [==============================] - 2s 462ms/step - loss: 0.4156 - accuracy: 0.8546 - val_loss: 0.8741 - val_accuracy: 0.7325
# Epoch 80/80
# 5/5 [==============================] - 2s 480ms/step - loss: 0.3784 - accuracy: 0.8482 - val_loss: 0.8335 - val_accuracy: 0.7452

# %%
#save the model for predictions
model.save("s2s")
# Out:
# INFO:tensorflow:Assets written to: s2s\assets
# INFO:tensorflow:Assets written to: s2s\assets

# %%
#load the model
model = load_model("s2s")

#generate random index
index = np.random.randint(0,len(x_test)-1)

#get the data of generated index from x_test
music_pattern = x_test[index]
out_pred=[] #it will store predicted notes

#iterate till 200 note is generated
for i in range(200):
    #reshape the music pattern
    music_pattern = music_pattern.reshape(1,len(music_pattern),1)
    #get the maximum probability value from the predicted output
    pred_index = np.argmax(model.predict(music_pattern))
    #get the note using predicted index and
    #append to the output prediction list
    out_pred.append(ind2note[pred_index])
    music_pattern = np.append(music_pattern,pred_index)
    #update the music pattern with one timestep ahead
    music_pattern = music_pattern[1:]
# Out:
# 1/1 [==============================] - 1s 680ms/step
# 1/1 [==============================] - 1s 649ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 31ms/step

# %%
output_notes = []
for offset,pattern in enumerate(out_pred):
    #if pattern is a chord instance
    if ('.' in pattern) or pattern.isdigit():
        #split notes from the chord
        notes_in_chord = pattern.split('.')
        notes = []
        for current_note in notes_in_chord:
            i_curr_note=int(current_note)
            #cast the current note to Note object and
            #append the current note
            new_note = note.Note(i_curr_note)
            new_note.storedInstrument = instrument.Piano()
            notes.append(new_note)
            #cast the current note to Chord object
            #offset will be 1 step ahead from the previous note
            #as it will prevent notes to stack up
            new_chord = chord.Chord(notes)
            new_chord.offset = offset
            output_notes.append(new_chord)
    else:
        #cast the pattern to Note object apply the offset and
        #append the note
        new_note = note.Note(pattern)
        new_note.offset = offset
        new_note.storedInstrument = instrument.Piano()
        output_notes.append(new_note)
        
#save the midi file
midi_stream = stream.Stream(output_notes)
midi_stream.write('midi', fp='pred_music.mid')
# Out:
# 'pred_music.mid'
